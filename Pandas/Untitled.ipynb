# %%
import os
os.listdir()
# Out:
# ['Untitled.ipynb',
#  'supermarkets.json',
#  'supermarkets.csv',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.xlsx',
#  '.ipynb_checkpoints',
#  'supermarkets-commas.txt']

# %%
import pandas
df1 = pandas.read_csv("supermarkets.csv")

# %%
df2 = pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.iloc?

# %%
df2.iloc[0:5,0:5]
# Out:
#            Address           City Country  Employees  ID
# 0     3666 21st St  San Francisco     USA          8   1
# 1   735 Dolores St  San Francisco     USA         15   2
# 2      332 Hill St  San Francisco     USA         25   3
# 3     3995 23rd St  San Francisco     USA         10   4
# 4  1056 Sanchez St  San Francisco     USA         12   5

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2.shape
# Out:
# (6, 7)

# %%
df2["TestColumn"] = ["1","","","","",""]
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State TestColumn
# 0          CA 94114          1
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2_t = df2.T
df2_t
# Out:
#                         0               1                 2              3  \
# Address      3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City        San Francisco   San Francisco     San Francisco  San Francisco
# Country               USA             USA               USA            USA
# Employees               8              15                25             10
# ID                      1               2                 3              4
# Name              Madeira     Bready Shop       Super River     Ben's Shop
# State            CA 94114        CA 94119  California 94114       CA 94114
# TestColumn              1
#
#                           4                5
# Address     1056 Sanchez St  551 Alvarado St
# City          San Francisco    San Francisco
# Country                 USA              USA
# Employees                12               20
# ID                        5                6
# Name                Sanchez       Richvalley
# ...

# %%
df2_t["6"]=["My Address","My City","My Country","My Employees","My ID","My Name","My State","My TestColumn"]
df2_t
df2 = df2_t.T
df2
# Out:
#            Address           City     Country     Employees     ID  \
# 0     3666 21st St  San Francisco         USA             8      1
# 1   735 Dolores St  San Francisco         USA            15      2
# 2      332 Hill St  San Francisco         USA            25      3
# 3     3995 23rd St  San Francisco         USA            10      4
# 4  1056 Sanchez St  San Francisco         USA            12      5
# 5  551 Alvarado St  San Francisco         USA            20      6
# 6       My Address        My City  My Country  My Employees  My ID
#
#           Name             State     TestColumn
# 0      Madeira          CA 94114              1
# 1  Bready Shop          CA 94119
# 2  Super River  California 94114
# 3   Ben's Shop          CA 94114
# 4      Sanchez        California
# 5   Richvalley          CA 94114
# 6      My Name          My State  My TestColumn

# %%
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
dir(pandas)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Panel4D',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseList',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p8',
# ...

# %%
import geopy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-8940c3473e3c> in <module>()
# ----> 1 import geopy
#
# ModuleNotFoundError: No module named 'geopy'

# %%
! pip freeze
# Out:
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.6
# anaconda-project==0.8.2
# appnope==0.1.0
# appscript==1.0.1
# asn1crypto==0.24.0
# astroid==2.1.0
# astropy==3.1
# atomicwrites==1.2.1
# attrs==18.2.0
# Babel==2.6.0
# backcall==0.1.0
# backports.os==0.1.1
# backports.shutil-get-terminal-size==1.0.0
# beautifulsoup4==4.6.3
# bitarray==0.8.3
# bkcharts==0.2
# blaze==0.11.3
# bleach==3.0.2
# bokeh==1.0.2
# boto==2.49.0
# Bottleneck==1.2.1
# certifi==2018.11.29
# cffi==1.11.5
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.6.1
# clyent==1.2.2
# colorama==0.4.1
# conda==4.5.12
# conda-build==3.17.6
# conda-verify==3.1.1
# contextlib2==0.5.5
# cryptography==2.4.2
# cycler==0.10.0
# Cython==0.29.2
# cytoolz==0.9.0.1
# dask==1.0.0
# datashape==0.5.4
# decorator==4.3.0
# defusedxml==0.5.0
# distributed==1.25.1
# docutils==0.14
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.10
# Flask==1.0.2
# Flask-Cors==3.0.7
# future==0.17.1
# ...
